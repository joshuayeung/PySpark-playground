# %%
file_location = "/FileStore/tables/game_skater_stats.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.format("csv").option("inferSchema", 
                                     True).option("header", 
                                                  True).load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>game_id</th><th>player_id</th><th>team_id</th><th>timeOnIce</th><th>assists</th><th>goals</th><th>shots</th><th>hits</th><th>powerPlayGoals</th><th>powerPlayAssists</th><th>penaltyMinutes</th><th>faceOffWins</th><th>faceoffTaken</th><th>takeaways</th><th>giveaways</th><th>shortHandedGoals</th><th>shortHandedAssists</th><th>blocked</th><th>plusMinus</th><th>evenTimeOnIce</th><th>shortHandedTimeOnIce</th><th>powerPlayTimeOnIce</th></tr></thead><tbody><tr><td>2011030221</td><td>8467412</td><td>1</td><td>999</td><td>0</td><td>0</td><td>1</td><td>3</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>-1</td><td>885</td><td>98</td><td>16</td></tr><tr><td>2011030221</td><td>8468501</td><td>1</td><td>1168</td><td>0</td><td>0</td><td>0</td><td>4</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0</td><td>767</td><td>401</td><td>0</td></tr><tr><td>2011030221</td><td>8470609</td><td>1</td><td>558</td><td>0</td><td>0</td><td>2</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>-1</td><td>542</td><td>0</td><td>16</td></tr><tr><td>2011030221</td><td>8471816</td><td>1</td><td>1134</td><td>0</td><td>0</td><td>1</td><td>4</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>-1</td><td>935</td><td>183</td><td>16</td></tr><tr><td>2011030221</td><td>8472410</td><td>1</td><td>436</td><td>0</td><td>0</td><td>1</td><td>3</td><td>0</td><td>0</td><td>0</td><td>3</td><td>6</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>-1</td><td>436</td><td>0</td><td>0</td></tr><tr><td>2011030221</td><td>8471233</td><td>1</td><td>1344</td><td>0</td><td>1</td><td>4</td><td>0</td><td>1</td><td>0</td><td>0</td><td>13</td><td>21</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>-1</td><td>949</td><td>239</td><td>156</td></tr><tr><td>2011030221</td><td>8470920</td><td>1</td><td>837</td><td>1</td><td>0</td><td>2</td><td>5</td><td>0</td><td>0</td><td>0</td><td>1</td><td>2</td><td>1</td><td>0</td><td>0</td><td>0</td><td>2</td><td>1</td><td>756</td><td>0</td><td>81</td></tr><tr><td>2011030221</td><td>8473646</td><td>1</td><td>465</td><td>0</td><td>0</td><td>2</td><td>3</td><td>0</td><td>0</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>-1</td><td>465</td><td>0</td><td>0</td></tr><tr><td>2011030221</td><td>8470610</td><td>1</td><td>1327</td><td>1</td><td>1</td><td>3</td><td>3</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>2</td><td>0</td><td>903</td><td>268</td><td>156</td></tr><tr><td>2011030221</td><td>8472382</td><td>1</td><td>1324</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>-2</td><td>1085</td><td>220</td><td>19</td></tr><tr><td>2011030221</td><td>8474641</td><td>1</td><td>947</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>6</td><td>17</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>703</td><td>163</td><td>81</td></tr><tr><td>2011030221</td><td>8460626</td><td>1</td><td>1560</td><td>0</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>1</td><td>1</td><td>1226</td><td>334</td><td>0</td></tr><tr><td>2011030221</td><td>8472394</td><td>1</td><td>901</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>802</td><td>0</td><td>99</td></tr><tr><td>2011030221</td><td>8464977</td><td>1</td><td>1248</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>2</td><td>1</t ...

# %%
df.write.save('/FileStore/parquet/game_skater_stats',
             format='parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read.load("/FileStore/parquet/game_skater_stats")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>game_id</th><th>player_id</th><th>team_id</th><th>timeOnIce</th><th>assists</th><th>goals</th><th>shots</th><th>hits</th><th>powerPlayGoals</th><th>powerPlayAssists</th><th>penaltyMinutes</th><th>faceOffWins</th><th>faceoffTaken</th><th>takeaways</th><th>giveaways</th><th>shortHandedGoals</th><th>shortHandedAssists</th><th>blocked</th><th>plusMinus</th><th>evenTimeOnIce</th><th>shortHandedTimeOnIce</th><th>powerPlayTimeOnIce</th></tr></thead><tbody><tr><td>2010020361</td><td>8470120</td><td>15</td><td>1060</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>2</td><td>0</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>817</td><td>145</td><td>98</td></tr><tr><td>2010020361</td><td>8471242</td><td>15</td><td>1524</td><td>0</td><td>0</td><td>0</td><td>3</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>1224</td><td>121</td><td>179</td></tr><tr><td>2010020361</td><td>8470294</td><td>15</td><td>464</td><td>1</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>464</td><td>0</td><td>0</td></tr><tr><td>2010020361</td><td>8471240</td><td>15</td><td>1426</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>1</td><td>1195</td><td>231</td><td>0</td></tr><tr><td>2010020361</td><td>8468434</td><td>19</td><td>1296</td><td>0</td><td>0</td><td>4</td><td>0</td><td>0</td><td>0</td><td>0</td><td>4</td><td>5</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>-1</td><td>975</td><td>42</td><td>279</td></tr><tr><td>2010020361</td><td>8469508</td><td>19</td><td>858</td><td>0</td><td>0</td><td>3</td><td>0</td><td>0</td><td>0</td><td>2</td><td>7</td><td>11</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>-1</td><td>831</td><td>27</td><td>0</td></tr><tr><td>2010020361</td><td>8470647</td><td>19</td><td>937</td><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>876</td><td>61</td><td>0</td></tr><tr><td>2010020361</td><td>8470729</td><td>19</td><td>642</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>630</td><td>12</td><td>0</td></tr><tr><td>2010020361</td><td>8466142</td><td>19</td><td>1281</td><td>0</td><td>0</td><td>2</td><td>5</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>2</td><td>-1</td><td>1229</td><td>49</td><td>3</td></tr><tr><td>2010020361</td><td>8467890</td><td>19</td><td>1009</td><td>0</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>879</td><td>130</td><td>0</td></tr><tr><td>2010020361</td><td>8473446</td><td>19</td><td>1580</td><td>1</td><td>0</td><td>3</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>-2</td><td>1318</td><td>37</td><td>225</td></tr><tr><td>2010020361</td><td>8473534</td><td>19</td><td>1071</td><td>0</td><td>0</td><td>3</td><td>1</td><td>0</td><td>0</td><td>0</td><td>5</td><td>13</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>737</td><td>76</td><td>258</td></tr><tr><td>2010020361</td><td>8471851</td><td>19</td><td>835</td><td>0</td><td>0</td><td>3</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>-1</td><td>634</td><td>0</td><td>201</td></tr><tr><td>2010020361</td><td>8474565</td><td>19</td><td>1358</td><td>0</td><td>0</td><td>3</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td ...

# %%
df = spark.read.load("s3a://my_bucket/game_skater_stats/*.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">IllegalArgumentException</span>                  Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2755491970086731&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>df <span class="ansiyellow">=</span> spark<span class="ansiyellow">.</span>read<span class="ansiyellow">.</span>load<span class="ansiyellow">(</span><span class="ansiblue">&quot;s3a://my_bucket/game_skater_stats/*.parquet&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansicyan">load</span><span class="ansiblue">(self, path, format, schema, **options)</span>
# <span class="ansigreen">    164</span>         self<span class="ansiyellow">.</span>options<span class="ansiyellow">(</span><span class="ansiyellow">**</span>options<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    165</span>         <span class="ansigreen">if</span> isinstance<span class="ansiyellow">(</span>path<span class="ansiyellow">,</span> basestring<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 166</span><span class="ansiyellow">             </span><span class="ansigreen">return</span> self<span class="ansiyellow">.</span>_df<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>_jreader<span class="ansiyellow">.</span>load<span class="ansiyellow">(</span>path<span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    167</span>         <span class="ansigreen">elif</span> path <span class="ansigreen">is</span> <span class="ansigreen">not</span> <span class="ansigreen">None</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    168</span>             <span class="ansigreen">if</span> type<span class="ansiyellow">(</span>path<span class="ansiyellow">)</span> <span class="ansiyellow">!=</span> list<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansicyan">__call__</span><span class="ansiblue">(self, *args)</span>
# <span class="ansigreen">   1255</span>         answer <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>gateway_client<span class="ansiyellow">.</span>send_command<span class="ansiyellow">(</span>command<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1256</span>         return_value = get_return_value(
# <span class="ansigreen">-&gt; 1257</span><span class="ansiyellow">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansigreen">   1258</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1259</span>         <span class="ansigreen">for</span> temp_arg <span class="ansigreen">in</span> temp_args<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansicyan">deco</span><span class="ansiblue">(*a, **kw)</span>
# <span class="ansigreen">     77</span>                 <span class="ansigreen">raise</span> QueryExecutionException<span class="ansiyellow">(</span>s<span class="ansiyellow">.</span>split<span class="ansiyellow">(</span><span class="ansiblue">&apos;: &apos;</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> stackTrace<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     78</span>             <span class="ansigreen">if</span> s<span class="ansiyellow">.</span>startswith<span class="ansiyellow">(</span><span class="ansiblue">&apos;java.lang.IllegalArgumentException: &apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 79</span><span class="ansiyellow">                 </span><span class="ansigreen">raise</span> IllegalArgumentException<span class="ansiyellow">(</span>s<span class="ansiyellow">.</span>split<span class="ansiyellow">(</span><span class="ansiblue">&apos;: &apos;</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> stackTrace<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     80</span>             <span class="ansigreen">raise</span><span class="ansiyellow"></span>
# <span class="ansigreen">     81</span>     <span class="ansigreen">return</span> deco<span class="ansiyellow"></span>
#
# <span class="ansired">IllegalArgumentException</span>: &quot;The bucket name parameter must be specified when requesting a bucket&apos;s location&quot;</div>

# %%
# DBFS (Parquet)
df.write.save('/FileStore/parquet/game_stats', format='parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# S3 (Parquet)
df.write.parquet("s3a://my_bucket/game_stats", mode="overwrite")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">IllegalArgumentException</span>                  Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2755491970086733&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># S3 (Parquet)</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>df<span class="ansiyellow">.</span>write<span class="ansiyellow">.</span>parquet<span class="ansiyellow">(</span><span class="ansiblue">&quot;s3a://my_bucket/game_stats&quot;</span><span class="ansiyellow">,</span> mode<span class="ansiyellow">=</span><span class="ansiblue">&quot;overwrite&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansicyan">parquet</span><span class="ansiblue">(self, path, mode, partitionBy, compression)</span>
# <span class="ansigreen">    841</span>             self<span class="ansiyellow">.</span>partitionBy<span class="ansiyellow">(</span>partitionBy<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    842</span>         self<span class="ansiyellow">.</span>_set_opts<span class="ansiyellow">(</span>compression<span class="ansiyellow">=</span>compression<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 843</span><span class="ansiyellow">         </span>self<span class="ansiyellow">.</span>_jwrite<span class="ansiyellow">.</span>parquet<span class="ansiyellow">(</span>path<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    844</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    845</span>     <span class="ansiyellow">@</span>since<span class="ansiyellow">(</span><span class="ansicyan">1.6</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansicyan">__call__</span><span class="ansiblue">(self, *args)</span>
# <span class="ansigreen">   1255</span>         answer <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>gateway_client<span class="ansiyellow">.</span>send_command<span class="ansiyellow">(</span>command<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1256</span>         return_value = get_return_value(
# <span class="ansigreen">-&gt; 1257</span><span class="ansiyellow">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansigreen">   1258</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1259</span>         <span class="ansigreen">for</span> temp_arg <span class="ansigreen">in</span> temp_args<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansicyan">deco</span><span class="ansiblue">(*a, **kw)</span>
# <span class="ansigreen">     77</span>                 <span class="ansigreen">raise</span> QueryExecutionException<span class="ansiyellow">(</span>s<span class="ansiyellow">.</span>split<span class="ansiyellow">(</span><span class="ansiblue">&apos;: &apos;</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> stackTrace<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     78</span>             <span class="ansigreen">if</span> s<span class="ansiyellow">.</span>startswith<span class="ansiyellow">(</span><span class="ansiblue">&apos;java.lang.IllegalArgumentException: &apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 79</span><span class="ansiyellow">                 </span><span class="ansigreen">raise</span> IllegalArgumentException<span class="ansiyellow">(</span>s<span class="ansiyellow">.</span>split<span class="ansiyellow">(</span><span class="ansiblue">&apos;: &apos;</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> stackTrace<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     80</span>             <span class="ansigreen">raise</span><span class="ansiyellow"></span>
# <span class="ansigreen">     81</span>     <span class="ansigreen">return</span> deco<span class="ansiyellow"></span>
#
# <span class="ansired">IllegalArgumentException</span>: &quot;The bucket name parameter must be specified when requesting a bucket&apos;s location&quot;</div>

# %%
# DBFS (CSV)
df.write.save('/FileStore/parquet/game_stats.csv', format='csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# S3 (CSV)
df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save(
"s3a://my_bucket/game_stats.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">IllegalArgumentException</span>                  Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2755491970086735&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># S3 (CSV)</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> df.coalesce(1).write.format(&quot;com.databricks.spark.csv&quot;).option(&quot;header&quot;, &quot;true&quot;).save(
# <span class="ansigreen">----&gt; 3</span><span class="ansiyellow"> &quot;s3a://my_bucket/game_stats.csv&quot;)
# </span>
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansicyan">save</span><span class="ansiblue">(self, path, format, mode, partitionBy, **options)</span>
# <span class="ansigreen">    736</span>             self<span class="ansiyellow">.</span>_jwrite<span class="ansiyellow">.</span>save<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    737</span>         <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 738</span><span class="ansiyellow">             </span>self<span class="ansiyellow">.</span>_jwrite<span class="ansiyellow">.</span>save<span class="ansiyellow">(</span>path<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    739</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    740</span>     <span class="ansiyellow">@</span>since<span class="ansiyellow">(</span><span class="ansicyan">1.4</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansicyan">__call__</span><span class="ansiblue">(self, *args)</span>
# <span class="ansigreen">   1255</span>         answer <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>gateway_client<span class="ansiyellow">.</span>send_command<span class="ansiyellow">(</span>command<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1256</span>         return_value = get_return_value(
# <span class="ansigreen">-&gt; 1257</span><span class="ansiyellow">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansigreen">   1258</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1259</span>         <span class="ansigreen">for</span> temp_arg <span class="ansigreen">in</span> temp_args<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansicyan">deco</span><span class="ansiblue">(*a, **kw)</span>
# <span class="ansigreen">     77</span>                 <span class="ansigreen">raise</span> QueryExecutionException<span class="ansiyellow">(</span>s<span class="ansiyellow">.</span>split<span class="ansiyellow">(</span><span class="ansiblue">&apos;: &apos;</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> stackTrace<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     78</span>             <span class="ansigreen">if</span> s<span class="ansiyellow">.</span>startswith<span class="ansiyellow">(</span><span class="ansiblue">&apos;java.lang.IllegalArgumentException: &apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 79</span><span class="ansiyellow">                 </span><span class="ansigreen">raise</span> IllegalArgumentException<span class="ansiyellow">(</span>s<span class="ansiyellow">.</span>split<span class="ansiyellow">(</span><span class="ansiblue">&apos;: &apos;</span><span class="ansiyellow">,</span> <span class="ansicyan">1</span><span class="ansiyellow">)</span><span class="ansiyellow">[</span><span class="ansicyan">1</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span> stackTrace<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     80</span>             <span class="ansigreen">raise</span><span class="ansiyellow"></span>
# <span class="ansigreen">     81</span>     <span class="ansigreen">return</span> deco<span class="ansiyellow"></span>
#
# <span class="ansired">IllegalArgumentException</span>: &quot;The bucket name parameter must be specified when requesting a bucket&apos;s location&quot;</div>

# %%
# Performing operations on Spark dataframes is via Spark SQL
df.createOrReplaceTempView("stats")

display(spark.sql("""
select player_id, sum(1) as games, sum(goals) as goals
from stats
group by 1
order by 3 desc
limit 5
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>player_id</th><th>games</th><th>goals</th></tr></thead><tbody><tr><td>8471214</td><td>788</td><td>434</td></tr><tr><td>8474564</td><td>655</td><td>342</td></tr><tr><td>8474141</td><td>748</td><td>311</td></tr><tr><td>8475166</td><td>700</td><td>308</td></tr><tr><td>8470794</td><td>782</td><td>305</td></tr></tbody></table></div>

# %%
display(spark.sql("""
select player_id, sum(1) as games, sum(goals) as goals
from stats
group by player_id
order by goals desc
limit 5
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>player_id</th><th>games</th><th>goals</th></tr></thead><tbody><tr><td>8471214</td><td>788</td><td>434</td></tr><tr><td>8474564</td><td>655</td><td>342</td></tr><tr><td>8474141</td><td>748</td><td>311</td></tr><tr><td>8475166</td><td>700</td><td>308</td></tr><tr><td>8470794</td><td>782</td><td>305</td></tr></tbody></table></div>

# %%
top_players = spark.sql("""
select player_id, sum(1) as games, sum(goals) as goals
from stats
group by 1
order by 3 desc
limit 5
""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# player names
file_location = "/FileStore/tables/player_info.csv"
names = spark.read.format("CSV").option("inferSchema", True).option("header", True).load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
top_players.createOrReplaceTempView("top_players")
names.createOrReplaceTempView("names")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(spark.sql("""
select p.player_id, goals, firstName, lastName
from top_players p
join names n
on p.player_id = n.player_id
order by 2 desc
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>player_id</th><th>goals</th><th>firstName</th><th>lastName</th></tr></thead><tbody><tr><td>8471214</td><td>434</td><td>Alex</td><td>Ovechkin</td></tr><tr><td>8474564</td><td>342</td><td>Steven</td><td>Stamkos</td></tr><tr><td>8474141</td><td>311</td><td>Patrick</td><td>Kane</td></tr><tr><td>8475166</td><td>308</td><td>John</td><td>Tavares</td></tr><tr><td>8470794</td><td>305</td><td>Joe</td><td>Pavelski</td></tr></tbody></table></div>

# %%
display(spark.sql("""
  select cast(substring(game_id, 1, 4) || '-' 
    || substring(game_id, 5, 2) || '-01' as Date) as month
    , sum(goals)/count(distinct game_id) as goals_per_goal
  from stats
  group by 1
  order by 1
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>goals_per_goal</th></tr></thead><tbody><tr><td>2010-02-01</td><td>5.464227642276422</td></tr><tr><td>2010-03-01</td><td>5.606741573033708</td></tr><tr><td>2011-02-01</td><td>5.3203252032520325</td></tr><tr><td>2011-03-01</td><td>4.837209302325581</td></tr><tr><td>2012-02-01</td><td>5.3069444444444445</td></tr><tr><td>2012-03-01</td><td>5.023255813953488</td></tr><tr><td>2013-02-01</td><td>5.342276422764227</td></tr><tr><td>2013-03-01</td><td>5.591397849462366</td></tr><tr><td>2014-02-01</td><td>5.324390243902439</td></tr><tr><td>2014-03-01</td><td>5.033707865168539</td></tr><tr><td>2015-02-01</td><td>5.337398373983739</td></tr><tr><td>2015-03-01</td><td>5.252747252747253</td></tr><tr><td>2016-02-01</td><td>5.4504065040650405</td></tr><tr><td>2016-03-01</td><td>5.160919540229885</td></tr><tr><td>2017-02-01</td><td>5.8607395751376865</td></tr><tr><td>2017-03-01</td><td>5.904761904761905</td></tr><tr><td>2018-02-01</td><td>5.961447678992919</td></tr><tr><td>2018-03-01</td><td>5.574712643678161</td></tr></tbody></table></div>

# %%
display(spark.sql("""
  select cast(goals/shots * 50 as int)/50.0 as Goals_per_shot
      ,sum(1) as Players 
  from (
    select player_id, sum(shots) as shots, sum(goals) as goals
    from stats
    group by 1
    having goals >= 5
  )  
  group by 1
  order by 1
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Goals_per_shot</th><th>Players</th></tr></thead><tbody><tr><td>0.0</td><td>3</td></tr><tr><td>0.02</td><td>99</td></tr><tr><td>0.04</td><td>220</td></tr><tr><td>0.06</td><td>194</td></tr><tr><td>0.08</td><td>217</td></tr><tr><td>0.1</td><td>230</td></tr><tr><td>0.12</td><td>142</td></tr><tr><td>0.14</td><td>37</td></tr><tr><td>0.16</td><td>21</td></tr><tr><td>0.18</td><td>5</td></tr><tr><td>0.2</td><td>3</td></tr><tr><td>0.32</td><td>1</td></tr></tbody></table></div>

# %%
# MLlib imports
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create a vector representation for features
assembler = VectorAssembler(inputCols=['shots', 'hits', 'assists',
                                      'penaltyMinutes', 'timeOnIce', 'takeaways'],
                           outputCol="features")
train_df = assembler.transform(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Fit a linear regression model
